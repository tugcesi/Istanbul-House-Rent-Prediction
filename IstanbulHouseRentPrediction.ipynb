# %% [markdown]
# # Istanbul House Rent Prediction

# %% [markdown]
# <img src='https://www.ekoturk.com/wp-content/uploads/2025/07/Istanbul-kira-artis-Istanbul.jpg'>

# %% [markdown]
# Bu çalışmada, İstanbul’daki kiralık konut ilanları Selenium kullanılarak derlenmiş; ancak ilanlarda fiyat, metrekare ve bina yaşı gibi kritik değişkenlerin eksik olması nedeniyle, güncel piyasa dinamiklerini yansıtacak şekilde kapsamlı bir veri simülasyonu gerçekleştirilmiştir.
#
# Simülasyon sürecinde; ilçe ve mahalle bazında kira seviyeleri, metrekare dağılımları, yapı yaşı, lçe/mahalle bazında sosyo-ekonomik gelişmişlik göstergeleri, bölgesel kademelenme yapısı ve kentsel dönüşüm alanları, güncel piyasa eğilimleri gibi faktörler dikkate alınarak gerçeğe en yakın olacak şekilde veri seti oluşturulmuştur.
#
# Elde edilen bu veri seti üzerinde, çeşitli makine öğrenmesi ve derin öğrenme algoritmaları uygulanarak konut kira fiyatlarının tahmin edilmesi amaçlanmıştır.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# Deep Learning imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# %%
df=pd.read_csv('istanbul_kiralik_complete.csv')

# %%
df.head()
# Out:
#                                               Başlık  \
# 0  Sarıyer Tarabya Boğaz Manzaralı Tripleks Bahçe...
# 1  Esenyurt Royal Garden 1+1 Kiralık Eşyalı Şehir...
# 2  Sultanbeyli'de Saklı Bahçe Evleri Sitesinde Ki...
# 3  Havaalanına Komşu Havuzlu Site İçinde Kiralık ...
# 4  Çok Merkezi Konumda 2. Kat Aydınlık  Boş Kiral...
#
#                                                Konum Oda Sayısı  Metrekare  \
# 0                  İstanbul / Sarıyer / Tarabya Mah.        4+1        NaN
# 1  İstanbul / Esenyurt / Barbaros Hayrettin Paşa ...        1+1        NaN
# 2          İstanbul / Sultanbeyli / Akşemsettin Mah.        3+1        NaN
# 3                    İstanbul / Pendik / Çamlık Mah.        3+1        NaN
# 4                 İstanbul / Beyoğlu / Firuzağa Mah.        NaN        NaN
#
#    Kat  Fiyat  Yapı Yaşı  Eşya  Isıtma  \
# 0  NaN    NaN        NaN   NaN     NaN
# 1  NaN    NaN        NaN   NaN     NaN
# 2  NaN    NaN        NaN   NaN     NaN
# 3  NaN    NaN        NaN   NaN     NaN
# 4  NaN    NaN        NaN   NaN     NaN
#
#                                                  URL
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ta...
# 1  https://www.hepsiemlak.com/istanbul-esenyurt-b...
# 2  https://www.hepsiemlak.com/istanbul-sultanbeyl...
# 3  https://www.hepsiemlak.com/istanbul-pendik-cam...
# 4  https://www.hepsiemlak.com/istanbul-beyoglu-fi...

# %%
# %run tugce_simulated_data_v01.py
# Out:
# Done. 9596 rows written to istanbul_kiralik_simulated.csv

# %%
df=pd.read_csv('istanbul_kiralik_simulated.csv')

# %%
df.head()
# Out:
#                                               Başlık  \
# 0  Sarıyer Tarabya Boğaz Manzaralı Tripleks Bahçe...
# 1  Esenyurt Royal Garden 1+1 Kiralık Eşyalı Şehir...
# 2  Sultanbeyli'de Saklı Bahçe Evleri Sitesinde Ki...
# 3  Havaalanına Komşu Havuzlu Site İçinde Kiralık ...
# 4  Çok Merkezi Konumda 2. Kat Aydınlık  Boş Kiral...
#
#                                                Konum Oda Sayısı  Metrekare  \
# 0                  İstanbul / Sarıyer / Tarabya Mah.        4+1        397
# 1  İstanbul / Esenyurt / Barbaros Hayrettin Paşa ...        1+1         53
# 2          İstanbul / Sultanbeyli / Akşemsettin Mah.        3+1        167
# 3                    İstanbul / Pendik / Çamlık Mah.        3+1        126
# 4                 İstanbul / Beyoğlu / Firuzağa Mah.        2+1         86
#
#    Kat   Fiyat  Yapı Yaşı     Eşya         Isıtma  \
# 0    9  433000          7  Eşyasız          Kombi
# 1    2   20000          7   Eşyalı  Soba/Doğalgaz
# 2    1   42000          8  Eşyasız        Merkezi
# 3    9   43000         18  Eşyasız          Kombi
# 4    2   56000          7   Eşyalı        Merkezi
#
#                                                  URL
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ta...
# 1  https://www.hepsiemlak.com/istanbul-esenyurt-b...
# 2  https://www.hepsiemlak.com/istanbul-sultanbeyl...
# 3  https://www.hepsiemlak.com/istanbul-pendik-cam...
# 4  https://www.hepsiemlak.com/istanbul-beyoglu-fi...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9596 entries, 0 to 9595
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Başlık      9596 non-null   object
#  1   Konum       9596 non-null   object
#  2   Oda Sayısı  9596 non-null   object
#  3   Metrekare   9596 non-null   int64
#  4   Kat         9596 non-null   int64
#  5   Fiyat       9596 non-null   int64
#  6   Yapı Yaşı   9596 non-null   int64
#  7   Eşya        9596 non-null   object
#  8   Isıtma      9596 non-null   object
#  9   URL         9596 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 749.8+ KB

# %%
df.isnull().sum()
# Out:
# Başlık        0
# Konum         0
# Oda Sayısı    0
# Metrekare     0
# Kat           0
# Fiyat         0
# Yapı Yaşı     0
# Eşya          0
# Isıtma        0
# URL           0
# dtype: int64

# %%
df.describe().T
# Out:
#             count          mean           std      min      25%      50%  \
# Metrekare  9596.0    122.511255     90.003341     20.0     79.0     96.0
# Kat        9596.0      6.477699      3.718694      0.0      3.0      7.0
# Fiyat      9596.0  60018.497291  66480.648696  10000.0  26500.0  38500.0
# Yapı Yaşı  9596.0     14.179241      9.468996      0.0      7.0     13.0
#
#                75%       max
# Metrekare    128.0    1650.0
# Kat           10.0      49.0
# Fiyat      61500.0  903500.0
# Yapı Yaşı     20.0      48.0

# %%
df.corr(numeric_only=True)
# Out:
#            Metrekare       Kat     Fiyat  Yapı Yaşı
# Metrekare   1.000000  0.052625  0.867122  -0.141178
# Kat         0.052625  1.000000  0.057883  -0.009083
# Fiyat       0.867122  0.057883  1.000000  -0.187539
# Yapı Yaşı  -0.141178 -0.009083 -0.187539   1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
#Feature Engineering

# %%
df['Baslik'] = df['Başlık'].str.lower()                          # küçük harfe çevir
df['Baslik'] = df['Baslik'].str.replace('\d+', '', regex=True)   # rakamları kaldır
df['Baslik'] = df['Baslik'].str.replace('\n|\r', ' ', regex=True) # satır sonlarını boşluğa çevir
df['Baslik'] = df['Baslik'].str.replace(r'[^\w\s]', '', regex=True) # noktalama kaldır
df['Baslik'] = df['Baslik'].str.strip()                    # baş/son boşlukları temizle

# %%
df[df['Baslik'].str.contains('satılık')]
# Out:
#                                                  Başlık  \
# 86      Ayışığından Yeni Binada 1+0 50 M2 Satılık Daire
# 92    Ev-Ser’den 5.Levent Korupark Acil Büyük Tip 4+...
# 2476  Çekmeköy Sosyal Donatılı Site İçi 3+1 Boş Satı...
# 4876  Başakkent Gölet 4+1 Geniş Ferah Temiz Satılık ...
# 5676  Bahçeşehir Konakları Muhteşem Manzara 6+2 Satı...
# 7420       Satılık Bağlar Çeşme Kiralık Daire 100 Metre
# 8089        Ispartakule Ebruli Sitesi 3+1 Satılık Daire
# 9212  Eyüpsultan Esentepe'de Merkezı Konumda 2+1 Sat...
# 9349             Skyland 1+1 Satılık Boş Daire Vt Uygun
# 9449           Kordon İstanbul 1+1 Eşyalı Satılık Daire
# 9465            Güncel Skyland 1+1 Fırsat Satılık Daire
# 9501  Maslak Ağaoğlu 1453 De Taşınmaya Hazır Satılık...
#
#                                                  Konum Oda Sayısı  Metrekare  \
# 86         İstanbul / Bahçelievler / Bahçelievler Mah.        1+0         50
# 92              İstanbul / Eyüpsultan / 5. Levent Mah.        4+1        187
# 2476             İstanbul / Çekmeköy / Cumhuriyet Mah.        3+1        152
# 4876  İstanbul / Başakşehir / Bahçeşehir 2. Kısım Mah.        4+1        190
# 5676  İstanbul / Başakşehir / Bahçeşehir 1. Kısım Mah.        6+2        412
# 7420                  İstanbul / Esenyurt / Çınar Mah.        2+1         94
# 8089               İstanbul / Avcılar / Tahtakale Mah.        3+1        139
# 9212             İstanbul / Eyüpsultan / Esentepe Mah.        2+1         99
# 9349                   İstanbul / Sarıyer / Huzur Mah.        1+1         59
# 9449              İstanbul / Kağıthane / Hamidiye Mah.        1+1         55
# 9465                   İstanbul / Sarıyer / Huzur Mah.        1+1         70
# 9501                  İstanbul / Sarıyer / Maslak Mah.        3+1        159
#
#       Kat   Fiyat  Yapı Yaşı     Eşya         Isıtma  \
# 86      1   20000          0  Eşyasız  Klima (Split)
# 92     10  117000          4  Eşyasız  Yerden Isıtma
# 2476    4   96500          5  Eşyasız  Klima (Split)
# 4876   10   96500          6   Eşyalı        Merkezi
# 5676   13  245000          5  Eşyasız          Kombi
# 7420    8   20000         19   Eşyalı          Kombi
# 8089    3   47000          7  Eşyasız  Soba/Doğalgaz
# 9212    5   53000          6   Eşyalı          Kombi
# 9349   12   35500          6  Eşyasız        Merkezi
# 9449   11   20000          5   Eşyalı        Merkezi
# 9465    6   39000         22  Eşyasız        Merkezi
# 9501    8   84500         11  Eşyasız          Kombi
#
#                                                     URL  \
# 86    https://www.hepsiemlak.com/istanbul-bahcelievl...
# 92    https://www.hepsiemlak.com/istanbul-eyupsultan...
# 2476  https://www.hepsiemlak.com/istanbul-cekmekoy-c...
# 4876  https://www.hepsiemlak.com/istanbul-basaksehir...
# 5676  https://www.hepsiemlak.com/istanbul-basaksehir...
# 7420  https://www.hepsiemlak.com/istanbul-esenyurt-c...
# 8089  https://www.hepsiemlak.com/istanbul-avcilar-ta...
# 9212  https://www.hepsiemlak.com/istanbul-eyupsultan...
# 9349  https://www.hepsiemlak.com/istanbul-sariyer-hu...
# 9449  https://www.hepsiemlak.com/istanbul-kagithane-...
# 9465  https://www.hepsiemlak.com/istanbul-sariyer-hu...
# 9501  https://www.hepsiemlak.com/istanbul-sariyer-ma...
#
#                                                  Baslik
# 86            ayışığından yeni binada   m satılık daire
# 92     evserden levent korupark acil büyük tip  satılık
# 2476  çekmeköy sosyal donatılı site içi  boş satılık...
# 4876   başakkent gölet  geniş ferah temiz satılık daire
# 5676  bahçeşehir konakları muhteşem manzara  satılık...
# 7420          satılık bağlar çeşme kiralık daire  metre
# 8089           ispartakule ebruli sitesi  satılık daire
# 9212  eyüpsultan esentepede merkezı konumda  satılık...
# 9349                skyland  satılık boş daire vt uygun
# 9449              kordon istanbul  eşyalı satılık daire
# 9465               güncel skyland  fırsat satılık daire
# 9501  maslak ağaoğlu  de taşınmaya hazır satılık  daire

# %%
df = df[~df['Baslik'].str.contains('satılık', case=False)]

# %%
df.shape
# Out:
# (9584, 11)

# %%
# İlçe kolonunu oluşturma 
df['Ilce'] = df['Konum'].str.split('/').str[1].str.strip()

# Mahalle kolonunu oluşturma
df['Mahalle'] = df['Konum'].str.split('/').str[2].str.strip().str.replace('Mah.', '', regex=False).str.strip()

# %%
#İlçe Bazında Ortalama Kira Fiyatı
import plotly.express as px

ilce_fiyat = df.groupby('Ilce')['Fiyat'].median().reset_index()
ilce_fiyat = ilce_fiyat.sort_values('Fiyat', ascending=False).head(20)

fig = px.bar(ilce_fiyat, 
             x='Ilce', y='Fiyat',
             color='Fiyat',
             color_continuous_scale='Blues',
             title='İlçe Bazında Ortalama Kira Fiyatı (Top 20)',
             labels={'Fiyat': 'Ort Fiyat (TL)', 'Ilce': 'İlçe'})
fig.show()

# %%
# İlçe Bazında Ortalama Metrekare
ilce_m2 = df.groupby('Ilce')['Metrekare'].median().reset_index()
ilce_m2 = ilce_m2.sort_values('Metrekare', ascending=False).head(20)

fig = px.bar(ilce_m2,
             x='Ilce', y='Metrekare',
             color='Metrekare',
             color_continuous_scale='RdPu',
             title='İlçe Bazında Ort Metrekare (Top 20)',
             labels={'Metrekare': 'Ort m²', 'Ilce': 'İlçe'})
fig.show()

# %%
# İlçe Bazında Ortalama Yapı Yaşı
ilce_yas = df.groupby('Ilce')['Yapı Yaşı'].median().reset_index()
ilce_yas = ilce_yas.sort_values('Yapı Yaşı', ascending=False).head(20)

fig = px.bar(ilce_yas,
             x='Ilce', y='Yapı Yaşı',
             color='Yapı Yaşı',
             color_continuous_scale='YlGnBu',
             title='İlçe Bazında Ort Yapı Yaşı (Top 20)',
             labels={'Yapı Yaşı': 'Ort Yapı Yaşı', 'Ilce': 'İlçe'})
fig.show()

# %%
# İlçe Bazında Fiyat + Metrekare + Yapı Yaşı
ilce_ozet = df.groupby('Ilce').agg(
    Fiyat      = ('Fiyat', 'median'),
    Metrekare  = ('Metrekare', 'median'),
    YapiYasi   = ('Yapı Yaşı', 'median'),
    Adet       = ('Fiyat', 'count')
).reset_index()

fig = px.scatter(ilce_ozet,
                 x='Metrekare', y='Fiyat',
                 size='Adet',
                 color='YapiYasi',
                 color_continuous_scale='turbo',
                 hover_name='Ilce',
                 title='İlçe Bazında Fiyat - Metrekare - Yapı Yaşı',
                 labels={
                     'Fiyat'     : 'Ortalama Fiyat (TL)',
                     'Metrekare' : 'Ortalama m²',
                     'YapiYasi'  : 'Yapı Yaşı',
                     'Adet'      : 'İlan Sayısı'
                 })
fig.show()

# %%
# Metrekare - Fiyat İlişkisi
plt.figure(figsize=(8, 5))
plt.scatter(df['Metrekare'], df['Fiyat'], alpha=0.3, color='steelblue', s=10)
plt.title('Metrekare - Fiyat İlişkisi')
plt.xlabel('Metrekare')
plt.ylabel('Fiyat (TL)')
plt.tight_layout()
plt.show()

# %%
df['KatKategori'] = pd.cut(df['Kat'], 
    bins=[-np.inf, -1, 0, 2, 7, 10, np.inf],
    labels=['Bodrum', 'Zemin Kat', 'Düşük Kat', 'Orta Kat', 'Yüksek Kat', 'Çok Yüksek Kat'])

# %%
df['BinaKategori'] = pd.cut(df['Yapı Yaşı'],
                             bins=[-1, 0, 5, 10, 20, 100],
                             labels=['Sıfır', 'YeniYapı', 'OrtaYaş', 'Eski', 'ÇokEski'])

# %%
# Bina Yaşı - Fiyat
bina_order = ['Sıfır', 'YeniYapı', 'OrtaYaş', 'Eski', 'ÇokEski']
bina_data  = [df[df['BinaKategori'] == k]['Fiyat'].values for k in bina_order]

plt.figure(figsize=(9, 5))
plt.boxplot(bina_data, labels=bina_order, patch_artist=True,
            boxprops=dict(facecolor='steelblue', color='white'),
            medianprops=dict(color='white', linewidth=2),
            whiskerprops=dict(color='steelblue'),
            capprops=dict(color='steelblue'),
            flierprops=dict(marker='o', markersize=2, alpha=0.3, color='steelblue'))
plt.title('Bina Yaşı Kategorisine Göre Fiyat Dağılımı')
plt.ylabel('Fiyat (TL)')
plt.tight_layout()
plt.show()

# %%
#Boğaz Manzaralı
df['BogazManzarali'] = df['Baslik'].apply(lambda x: 'boğaz' in x and 'manzara' in x)

# %%
#Manzara
df['Manzarali'] = df['Baslik'].apply(lambda x: 'manzara' in x)

# %%
# Dubleks, Triplex veya teraslı geçenler
df['Dubleks'] = df['Baslik'].str.contains('dubleks|teraslı', case=False, na=False)
df['Tripleks'] = df['Baslik'].str.contains('tripleks|triplex', case=False, na=False)

# %%
# Metro veya metrobüs veya marmaray 
df['TopluTasima'] = df['Baslik'].str.contains('metro|metrobüs|marmaray', case=False, na=False)

# Hem metro hem metrobüs
df['TopluTasima2x'] = df['Baslik'].apply(lambda x: 'metro' in str(x).lower() and 'metrobüs' in str(x).lower())

# %%
# Üni veya ünv veya üniversite
df['Universite'] = df['Baslik'].str.contains('üni|ünv|üniversite', case=False, na=False)

# %%
# Hastane
df['Hastane'] = df['Baslik'].str.contains('hastane', case=False, na=False)

# %%
# Havuz
df['Havuz'] = df['Baslik'].str.contains('havuz', case=False, na=False)

# %%
# Balkon
df['Balkon'] = df['Baslik'].str.contains('balkon', case=False, na=False)

# %%
# Lüks ya da lüx ya da lux 
df['Luks'] = df['Baslik'].str.contains('lüks|lüx|lux', case=False, na=False)

# %%
# Cadde geçenler
df['Cadde'] = df['Baslik'].str.contains('cadde', case=False, na=False)

# %%
# Residence ya da rezidans
df['Rezidans'] = df['Baslik'].str.contains('residence|rezidans', case=False, na=False)

# %%
# AVM
df['AvmyeYakinlik'] = df['Baslik'].str.contains('avm', case=False, na=False)

# %%
# Asansör 
df['Asansor'] = df['Baslik'].str.contains('asansör', case=False, na=False)

# %%
# Site ya da konak
df['Site'] = df['Baslik'].str.contains('site|konak', case=False, na=False)

# %%
# Villa 
df['Villa'] = df['Baslik'].str.contains('villa', case=False, na=False)

# Yalı
df['Yali'] = df['Baslik'].str.contains('yalı', case=False, na=False)

# %%
# Güvenlik
df['Guvenlik'] = df['Baslik'].str.contains('güvenlik', case=False, na=False)

# %%
# Otopark
df['Otopark'] = df['Baslik'].str.contains('otopark', case=False, na=False)

# %%
# Orman ya da doğaya yakınlık
df['DogayaYakinlik'] = df['Baslik'].str.contains('orman|doğa|doga', case=False, na=False)

# %%
# Peyzaj ya da peysaj 
df['Peyzaj'] = df['Baslik'].str.contains('peyzaj|peysaj', case=False, na=False)

# Bahçe
df['Bahce'] = df['Baslik'].str.contains('bahçe', case=False, na=False)

# %%
# Sahil ya da iskele ya da deniz
df['SahileYakinlik'] = df['Baslik'].str.contains('sahil|iskele|deniz', case=False, na=False)

# %%
# Tadilat ya da yenilenmiş
df['Restorasyon'] = df['Baslik'].str.contains('tadilat|yenilenmiş', case=False, na=False)

# %%
# Merkez ya da meydan
df['MerkezeYakinlik'] = df['Baslik'].str.contains('merkez|meydan', case=False, na=False)

# %%
# Okul ya da kolej 
df['OkulaYakinlik'] = df['Baslik'].str.contains('okul|kolej|lise', case=False, na=False)

# %%
# Havaalanı
df['HavaalanınaYakinlik'] = df['Baslik'].str.contains('havaalanı', case=False, na=False)

# %%
# Bodrum
df['Bodrum'] = df['Baslik'].str.contains('bodrum', case=False, na=False)

# %%
# Sıfır Yapı
df['Sıfır'] = df['Baslik'].str.contains('sıfır', case=False, na=False)

# %%
df.head()
# Out:
#                                               Başlık  \
# 0  Sarıyer Tarabya Boğaz Manzaralı Tripleks Bahçe...
# 1  Esenyurt Royal Garden 1+1 Kiralık Eşyalı Şehir...
# 2  Sultanbeyli'de Saklı Bahçe Evleri Sitesinde Ki...
# 3  Havaalanına Komşu Havuzlu Site İçinde Kiralık ...
# 4  Çok Merkezi Konumda 2. Kat Aydınlık  Boş Kiral...
#
#                                                Konum Oda Sayısı  Metrekare  \
# 0                  İstanbul / Sarıyer / Tarabya Mah.        4+1        397
# 1  İstanbul / Esenyurt / Barbaros Hayrettin Paşa ...        1+1         53
# 2          İstanbul / Sultanbeyli / Akşemsettin Mah.        3+1        167
# 3                    İstanbul / Pendik / Çamlık Mah.        3+1        126
# 4                 İstanbul / Beyoğlu / Firuzağa Mah.        2+1         86
#
#    Kat   Fiyat  Yapı Yaşı     Eşya         Isıtma  \
# 0    9  433000          7  Eşyasız          Kombi
# 1    2   20000          7   Eşyalı  Soba/Doğalgaz
# 2    1   42000          8  Eşyasız        Merkezi
# 3    9   43000         18  Eşyasız          Kombi
# 4    2   56000          7   Eşyalı        Merkezi
#
#                                                  URL  ... DogayaYakinlik  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ta...  ...          False
# 1  https://www.hepsiemlak.com/istanbul-esenyurt-b...  ...          False
# 2  https://www.hepsiemlak.com/istanbul-sultanbeyl...  ...          False
# 3  https://www.hepsiemlak.com/istanbul-pendik-cam...  ...          False
# 4  https://www.hepsiemlak.com/istanbul-beyoglu-fi...  ...          False
#
#   Peyzaj  Bahce SahileYakinlik Restorasyon  MerkezeYakinlik  OkulaYakinlik  \
# 0  False   True          False       False            False          False
# 1  False  False          False       False            False          False
# 2  False   True          False       False            False          False
# 3  False  False          False       False            False          False
# 4  False  False          False       False             True          False
#
#    HavaalanınaYakinlik  Bodrum  Sıfır
# 0                False   False  False
# 1                False   False  False
# 2                False   False  False
# 3                 True   False  False
# 4                False   False  False
#
# [5 rows x 45 columns]

# %%
sns.boxplot(x=df['Fiyat']);

# %%
df['Fiyat'].mean()+3*df['Fiyat'].std()
# Out:
# np.float64(259459.09265669304)

# %%
sns.boxplot(x=df['Metrekare']);

# %%
df['Metrekare'].mean()+3*df['Metrekare'].std()
# Out:
# np.float64(392.47343111241634)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9584 entries, 0 to 9595
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Başlık               9584 non-null   object
#  1   Konum                9584 non-null   object
#  2   Oda Sayısı           9584 non-null   object
#  3   Metrekare            9584 non-null   int64
#  4   Kat                  9584 non-null   int64
#  5   Fiyat                9584 non-null   int64
#  6   Yapı Yaşı            9584 non-null   int64
#  7   Eşya                 9584 non-null   object
#  8   Isıtma               9584 non-null   object
#  9   URL                  9584 non-null   object
#  10  Baslik               9584 non-null   object
#  11  Ilce                 9584 non-null   object
#  12  Mahalle              9584 non-null   object
#  13  KatKategori          9584 non-null   category
#  14  BinaKategori         9584 non-null   category
#  15  BogazManzarali       9584 non-null   bool
#  16  Manzarali            9584 non-null   bool
#  17  Dubleks              9584 non-null   bool
#  18  Tripleks             9584 non-null   bool
#  19  TopluTasima          9584 non-null   bool
#  20  TopluTasima2x        9584 non-null   bool
#  21  Universite           9584 non-null   bool
#  22  Hastane              9584 non-null   bool
#  23  Havuz                9584 non-null   bool
#  24  Balkon               9584 non-null   bool
#  25  Luks                 9584 non-null   bool
#  26  Cadde                9584 non-null   bool
#  27  Rezidans             9584 non-null   bool
#  28  AvmyeYakinlik        9584 non-null   bool
#  29  Asansor              9584 non-null   bool
#  30  Site                 9584 non-null   bool
#  31  Villa                9584 non-null   bool
#  32  Yali                 9584 non-null   bool
#  33  Guvenlik             9584 non-null   bool
#  34  Otopark              9584 non-null   bool
#  35  DogayaYakinlik       9584 non-null   bool
#  36  Peyzaj               9584 non-null   bool
#  37  Bahce                9584 non-null   bool
#  38  SahileYakinlik       9584 non-null   bool
#  39  Restorasyon          9584 non-null   bool
#  40  MerkezeYakinlik      9584 non-null   bool
#  41  OkulaYakinlik        9584 non-null   bool
#  42  HavaalanınaYakinlik  9584 non-null   bool
#  43  Bodrum               9584 non-null   bool
#  44  Sıfır                9584 non-null   bool
# dtypes: bool(30), category(2), int64(4), object(9)
# memory usage: 1.3+ MB

# %%
# Oda ve Salon sayısını ayrı ayrı alalım
df['OdaSayisi'] = df['Oda Sayısı'].str.split('+').str[0].astype(int)
df['SalonSayisi'] = df['Oda Sayısı'].str.split('+').str[1].astype(int)

# %%
premium_kolonlar = ['BogazManzarali', 'Manzarali', 'Havuz', 'Guvenlik', 
                    'Otopark', 'Asansor', 'Balkon', 'Bahce', 'Luks', 
                    'Rezidans', 'Yali', 'Villa', 'Peyzaj']

df['PremiumSkor'] = df[premium_kolonlar].sum(axis=1)

# %%
ulasim_kolonlar = ['TopluTasima', 'TopluTasima2x', 'AvmyeYakinlik', 
                   'HavaalanınaYakinlik', 'MerkezeYakinlik']

df['UlasimSkor'] = df[ulasim_kolonlar].sum(axis=1)

# %%
# Eşya
df['Esya'] = df['Eşya'].map({'Eşyalı': 1, 'Eşyasız': 0})

# Isıtma
isitma_map = {
    'Merkezi'       : 3,
    'Kombi'         : 2,
    'Soba/Doğalgaz' : 1,
    'Yok'           : 0
}
df['Isıtma'] = df['Isıtma'].map(isitma_map)

# %%
df.isnull().sum()
# Out:
# Başlık                    0
# Konum                     0
# Oda Sayısı                0
# Metrekare                 0
# Kat                       0
# Fiyat                     0
# Yapı Yaşı                 0
# Eşya                      0
# Isıtma                 1287
# URL                       0
# Baslik                    0
# Ilce                      0
# Mahalle                   0
# KatKategori               0
# BinaKategori              0
# BogazManzarali            0
# Manzarali                 0
# Dubleks                   0
# Tripleks                  0
# TopluTasima               0
# TopluTasima2x             0
# Universite                0
# Hastane                   0
# Havuz                     0
# Balkon                    0
# Luks                      0
# Cadde                     0
# Rezidans                  0
# AvmyeYakinlik             0
# Asansor                   0
# Site                      0
# Villa                     0
# Yali                      0
# Guvenlik                  0
# Otopark                   0
# DogayaYakinlik            0
# Peyzaj                    0
# Bahce                     0
# SahileYakinlik            0
# Restorasyon               0
# MerkezeYakinlik           0
# OkulaYakinlik             0
# HavaalanınaYakinlik       0
# Bodrum                    0
# Sıfır                     0
# OdaSayisi                 0
# SalonSayisi               0
# PremiumSkor               0
# UlasimSkor                0
# Esya                      0
# dtype: int64

# %%
# Nulları medyanla dolduralım ya da silsek de olur
df['Isıtma'].fillna(df['Isıtma'].median(), inplace=True)

# %%
df.head()
# Out:
#                                               Başlık  \
# 0  Sarıyer Tarabya Boğaz Manzaralı Tripleks Bahçe...
# 1  Esenyurt Royal Garden 1+1 Kiralık Eşyalı Şehir...
# 2  Sultanbeyli'de Saklı Bahçe Evleri Sitesinde Ki...
# 3  Havaalanına Komşu Havuzlu Site İçinde Kiralık ...
# 4  Çok Merkezi Konumda 2. Kat Aydınlık  Boş Kiral...
#
#                                                Konum Oda Sayısı  Metrekare  \
# 0                  İstanbul / Sarıyer / Tarabya Mah.        4+1        397
# 1  İstanbul / Esenyurt / Barbaros Hayrettin Paşa ...        1+1         53
# 2          İstanbul / Sultanbeyli / Akşemsettin Mah.        3+1        167
# 3                    İstanbul / Pendik / Çamlık Mah.        3+1        126
# 4                 İstanbul / Beyoğlu / Firuzağa Mah.        2+1         86
#
#    Kat   Fiyat  Yapı Yaşı     Eşya  Isıtma  \
# 0    9  433000          7  Eşyasız     2.0
# 1    2   20000          7   Eşyalı     1.0
# 2    1   42000          8  Eşyasız     3.0
# 3    9   43000         18  Eşyasız     2.0
# 4    2   56000          7   Eşyalı     3.0
#
#                                                  URL  ... MerkezeYakinlik  \
# 0  https://www.hepsiemlak.com/istanbul-sariyer-ta...  ...           False
# 1  https://www.hepsiemlak.com/istanbul-esenyurt-b...  ...           False
# 2  https://www.hepsiemlak.com/istanbul-sultanbeyl...  ...           False
# 3  https://www.hepsiemlak.com/istanbul-pendik-cam...  ...           False
# 4  https://www.hepsiemlak.com/istanbul-beyoglu-fi...  ...            True
#
#   OkulaYakinlik HavaalanınaYakinlik Bodrum  Sıfır  OdaSayisi  SalonSayisi  \
# 0         False               False  False  False          4            1
# 1         False               False  False  False          1            1
# 2         False               False  False  False          3            1
# 3         False                True  False  False          3            1
# 4         False               False  False  False          2            1
#
#    PremiumSkor  UlasimSkor  Esya
# 0            3           0     0
# 1            1           0     1
# 2            1           0     0
# 3            1           1     0
# 4            0           1     1
#
# [5 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9584 entries, 0 to 9595
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Başlık               9584 non-null   object
#  1   Konum                9584 non-null   object
#  2   Oda Sayısı           9584 non-null   object
#  3   Metrekare            9584 non-null   int64
#  4   Kat                  9584 non-null   int64
#  5   Fiyat                9584 non-null   int64
#  6   Yapı Yaşı            9584 non-null   int64
#  7   Eşya                 9584 non-null   object
#  8   Isıtma               9584 non-null   float64
#  9   URL                  9584 non-null   object
#  10  Baslik               9584 non-null   object
#  11  Ilce                 9584 non-null   object
#  12  Mahalle              9584 non-null   object
#  13  KatKategori          9584 non-null   category
#  14  BinaKategori         9584 non-null   category
#  15  BogazManzarali       9584 non-null   bool
#  16  Manzarali            9584 non-null   bool
#  17  Dubleks              9584 non-null   bool
#  18  Tripleks             9584 non-null   bool
#  19  TopluTasima          9584 non-null   bool
#  20  TopluTasima2x        9584 non-null   bool
#  21  Universite           9584 non-null   bool
#  22  Hastane              9584 non-null   bool
#  23  Havuz                9584 non-null   bool
#  24  Balkon               9584 non-null   bool
#  25  Luks                 9584 non-null   bool
#  26  Cadde                9584 non-null   bool
#  27  Rezidans             9584 non-null   bool
#  28  AvmyeYakinlik        9584 non-null   bool
#  29  Asansor              9584 non-null   bool
#  30  Site                 9584 non-null   bool
#  31  Villa                9584 non-null   bool
#  32  Yali                 9584 non-null   bool
#  33  Guvenlik             9584 non-null   bool
#  34  Otopark              9584 non-null   bool
#  35  DogayaYakinlik       9584 non-null   bool
#  36  Peyzaj               9584 non-null   bool
#  37  Bahce                9584 non-null   bool
#  38  SahileYakinlik       9584 non-null   bool
#  39  Restorasyon          9584 non-null   bool
#  40  MerkezeYakinlik      9584 non-null   bool
#  41  OkulaYakinlik        9584 non-null   bool
#  42  HavaalanınaYakinlik  9584 non-null   bool
#  43  Bodrum               9584 non-null   bool
#  44  Sıfır                9584 non-null   bool
#  45  OdaSayisi            9584 non-null   int64
#  46  SalonSayisi          9584 non-null   int64
#  47  PremiumSkor          9584 non-null   int64
#  48  UlasimSkor           9584 non-null   int64
#  49  Esya                 9584 non-null   int64
# dtypes: bool(30), category(2), float64(1), int64(9), object(8)
# memory usage: 1.7+ MB

# %%
#Correlation by Fiyat
abs(df.corr(numeric_only=True))['Fiyat'].sort_values(ascending=False)
# Out:
# Fiyat                  1.000000
# Metrekare              0.866993
# OdaSayisi              0.408118
# Dubleks                0.400155
# Villa                  0.394468
# SalonSayisi            0.217969
# Yapı Yaşı              0.187399
# PremiumSkor            0.128557
# Manzarali              0.121132
# Tripleks               0.118146
# SahileYakinlik         0.111331
# BogazManzarali         0.102381
# Bahce                  0.101374
# Havuz                  0.096615
# Yali                   0.091832
# UlasimSkor             0.076509
# TopluTasima            0.060538
# Kat                    0.057366
# Isıtma                 0.057179
# TopluTasima2x          0.054862
# Balkon                 0.051423
# DogayaYakinlik         0.047064
# Esya                   0.042266
# Site                   0.042076
# Rezidans               0.034231
# Restorasyon            0.030076
# MerkezeYakinlik        0.028948
# Peyzaj                 0.027851
# AvmyeYakinlik          0.026815
# Luks                   0.026327
# Universite             0.016891
# Hastane                0.014769
# Bodrum                 0.014632
# Asansor                0.014549
# Otopark                0.013164
# Sıfır                  0.013122
# HavaalanınaYakinlik    0.009529
# OkulaYakinlik          0.008662
# Guvenlik               0.000828
# Cadde                  0.000389
# Name: Fiyat, dtype: float64

# %%
features = [
    'Metrekare',
    'OdaSayisi',
    'SalonSayisi',
    'Kat',  
    'Yapı Yaşı',
    'Villa', 
    'Dubleks', 
    'Tripleks', 
    'Yali',
    'BogazManzarali', 
    'Manzarali', 
    'SahileYakinlik',
    'Bahce', 
    'Havuz',
    'Ilce', 
    'Mahalle',
    'UlasimSkor'
    
]

x = df[features]

# %%
x.head()
# Out:
#    Metrekare  OdaSayisi  SalonSayisi  Kat  Yapı Yaşı  Villa  Dubleks  \
# 0        397          4            1    9          7  False    False
# 1         53          1            1    2          7  False    False
# 2        167          3            1    1          8  False    False
# 3        126          3            1    9         18  False    False
# 4         86          2            1    2          7  False    False
#
#    Tripleks   Yali  BogazManzarali  Manzarali  SahileYakinlik  Bahce  Havuz  \
# 0      True  False            True       True           False   True  False
# 1     False   True           False      False           False  False  False
# 2     False  False           False      False           False   True  False
# 3     False  False           False      False           False  False   True
# 4     False  False           False      False           False  False  False
#
#           Ilce                  Mahalle  UlasimSkor
# 0      Sarıyer                  Tarabya           0
# 1     Esenyurt  Barbaros Hayrettin Paşa           0
# 2  Sultanbeyli              Akşemsettin           0
# 3       Pendik                   Çamlık           1
# 4      Beyoğlu                 Firuzağa           1

# %%
x=pd.get_dummies(x, drop_first=True)

# %%
x.shape
# Out:
# (9584, 649)

# %%
y=df['Fiyat']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test=train_test_split(x,y, random_state=42, test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
model=lr.fit(x_train, y_train)

# %%
tahmin=lr.predict(x_test)

# %%
r2_score(y_test,tahmin)
# Out:
# 0.869114446224656

# %%
mean_squared_error(y_test,tahmin)**0.5
# Out:
# 24490.38413977319

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error


def algo_test(x,y):
        #Bütün modelleri tanımlıyorum
        L=LinearRegression()
        R=Ridge()
        Lass=Lasso()
        E=ElasticNet()
        ETR=ExtraTreeRegressor()
        GBR=GradientBoostingRegressor()
        kn=KNeighborsRegressor()
        dt=DecisionTreeRegressor()
        xgb=XGBRegressor()
       
        
        algos=[L,R,Lass,E,ETR,GBR,kn,dt,xgb]
        algo_names=['Linear','Ridge','Lasso','ElasticNet','Extra Tree','Gradient Boosting','KNeighborsRegressor','Decision Tree','XGBRegressor']
        
        x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.2,random_state=42)
        
        r_squared= []
        rmse= []
        mae= []
        
        #Hata ve doğruluk oranlarını bir tablo haline getirmek için bir dataframe oluşturuyorum
        result=pd.DataFrame(columns=['R_Squared','RMSE','MAE'],index=algo_names)
        
        
        for algo in algos:
            p=algo.fit(x_train,y_train).predict(x_test)
            r_squared.append(r2_score(y_test,p))
            rmse.append(mean_squared_error(y_test,p)**.5)
            mae.append(mean_absolute_error(y_test,p))
        
            

        #result adlı tabloya doğruluk ve hata oranlarımı yerleştiriyorum
        result.R_Squared=r_squared
        result.RMSE=rmse
        result.MAE=mae
        
       #oluşturduğum result tablosunu doğruluk oranına (r2_score) göre sıralayıp dönüyor
        rtable=result.sort_values('R_Squared',ascending=False)
        return rtable

# %%
algo_test(x,y)
# Out:
#                      R_Squared          RMSE           MAE
# XGBRegressor          0.937048  16984.503054   7648.023926
# Gradient Boosting     0.900413  21362.502164  11386.257514
# Ridge                 0.870610  24350.056253  12283.917901
# Linear                0.869114  24490.384140  12531.783076
# Lasso                 0.869104  24491.380292  12358.698990
# Decision Tree         0.838737  27184.271397  11406.885759
# Extra Tree            0.797447  30466.292293  11730.568597
# ElasticNet            0.771814  32336.609994  18217.269860
# KNeighborsRegressor   0.743888  34258.186446  19536.671883

# %%
#pip uninstall yellowbrick scikit-learn -y

# %%
#pip install scikit-learn yellowbrick

# %%
from yellowbrick.regressor import ResidualsPlot


model = XGBRegressor()
model.fit(x_train, y_train)
tahmin = model.predict(x_test)


vis = ResidualsPlot(model, force_model=True)
vis.fit(x_train, y_train)
vis.score(x_test, y_test)
vis.show()
# Out:
# <Axes: title={'center': 'Residuals for XGBRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
residuals=y_test-tahmin

# %%
sns.kdeplot(x=residuals, fill=True)
# Out:
# <Axes: xlabel='Fiyat', ylabel='Density'>

# %%
karsilastirma=pd.DataFrame()
karsilastirma['GercekFiyat']=y_test
karsilastirma['Tahmin']=tahmin
karsilastirma.head()
# Out:
#       GercekFiyat        Tahmin
# 3671        43000  40542.875000
# 7053        48500  65197.566406
# 2438        33000  30543.882812
# 4613        21500  20656.501953
# 5944        31000  32680.445312

# %%
# Regression with Deep Learning

# %%
x = df[[                    
    'Metrekare',
    'OdaSayisi',
    'SalonSayisi',
    'Kat',
    'Yapı Yaşı',
    'Villa',
    'Dubleks',
    'Tripleks',
    'Yali',
    'BogazManzarali',
    'Manzarali',
    'SahileYakinlik',
    'Bahce',
    'Havuz',
    'Ilce',
    'Mahalle',
    'UlasimSkor'
]]

y = df['Fiyat']

# %%
x=pd.get_dummies(x, drop_first=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train) 
x_test  = scaler.transform(x_test)

# %%
model = Sequential([
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)                               
])

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=64, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 7931748352.0000 - val_loss: 8173463552.0000
# Epoch 2/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7029872128.0000 - val_loss: 6376356864.0000
# Epoch 3/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 3652783360.0000 - val_loss: 2607849984.0000
# Epoch 4/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1139114496.0000 - val_loss: 1134386688.0000
# Epoch 5/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 791890176.0000 - val_loss: 714975936.0000
# Epoch 6/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 629891648.0000 - val_loss: 576016512.0000
# Epoch 7/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 616808064.0000 - val_loss: 579544384.0000
# Epoch 8/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 528865216.0000 - val_loss: 552184000.0000
# Epoch 9/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 536699616.0000 - val_loss: 528046208.0000
# Epoch 10/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 485631584.0000 - val_loss: 544306304.0000
# Epoch 11/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 446216448.0000 - val_loss: 513751200.0000
# Epoch 12/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 439288544.0000 - val_loss: 514517184.0000
# Epoch 13/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 421165184.0000 - val_loss: 517565312.0000
# Epoch 14/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 403058496.0000 - val_loss: 492369632.0000
# Epoch 15/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 420518112.0000 - val_loss: 509637184.0000
# Epoch 16/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 360277408.0000 - val_loss: 500650560.0000
# Epoch 17/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 409451808.0000 - val_loss: 530072544.0000
# Epoch 18/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 366097888.0000 - val_loss: 568983872.0000
# Epoch 19/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 358526784.0000 - val_loss: 513724512.0000
# Epoch 20/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 355235008.0000 - val_loss: 553377344.0000
# Epoch 21/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 341431936.0000 - val_loss: 492305408.0000
# Epoch 22/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 332764544.0000 - val_loss: 541382784.0000
# Epoch 23/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 328559904.0000 - val_loss: 545875328.0000
# Epoch 24/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 313154144.0000 - val_loss: 490970912.0000
# Epoch 25/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 313979712.0000 - val_loss: 517327552.0000
# Epoch 26/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 320196960.0000 - val_loss: 470444800.0000
# Epoch 27/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 302369216.0000 - val_loss: 480962816.0000
# Epoch 28/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 292143744.0000 - val_loss: 459866496.0000
# Epoch 29/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 320203968.0000 - val_loss: 429844480.0000
# Epoch 30/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 303332256.0000 - val_loss: 449946688.0000
# Epoch 31/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 317586432.0000 - val_loss: 463069408.0000
# Epoch 32/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 283699104.0000 - val_loss: 456573152.0000
# Epoch 33/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 276363264.0000 - val_loss: 446557568.0000
# Epoch 34/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 300286144.0000 - val_loss: 428647136.0000
# Epoch 35/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 277845184.0000 - val_loss: 453297696.0000
# Epoch 36/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 264594000.0000 - val_loss: 424403456.0000
# Epoch 37/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 264062864.0000 - val_loss: 450153120.0000
# Epoch 38/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 286788640.0000 - val_loss: 446293856.0000
# Epoch 39/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 262839792.0000 - val_loss: 447370112.0000
# Epoch 40/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 260396192.0000 - val_loss: 435636320.0000
# Epoch 41/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 247431440.0000 - val_loss: 407640640.0000
# Epoch 42/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 281070688.0000 - val_loss: 408547328.0000
# Epoch 43/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 269320544.0000 - val_loss: 391886944.0000
# Epoch 44/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 261350464.0000 - val_loss: 440673568.0000
# Epoch 45/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 260831888.0000 - val_loss: 409329216.0000
# Epoch 46/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 255669680.0000 - val_loss: 380263232.0000
# Epoch 47/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 243972352.0000 - val_loss: 415719264.0000
# Epoch 48/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 259252208.0000 - val_loss: 409334432.0000
# Epoch 49/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 221072848.0000 - val_loss: 378353824.0000
# Epoch 50/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 247575168.0000 - val_loss: 371209216.0000
# Epoch 51/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 248422944.0000 - val_loss: 351695328.0000
# Epoch 52/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 244329728.0000 - val_loss: 352544640.0000
# Epoch 53/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 249556144.0000 - val_loss: 375341728.0000
# Epoch 54/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 243283504.0000 - val_loss: 353960928.0000
# Epoch 55/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 258369584.0000 - val_loss: 458140512.0000
# Epoch 56/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 245009136.0000 - val_loss: 406494976.0000
# Epoch 57/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 247857248.0000 - val_loss: 372931808.0000
# Epoch 58/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 229755600.0000 - val_loss: 414568320.0000
# Epoch 59/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 251518432.0000 - val_loss: 364823136.0000
# Epoch 60/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 248667152.0000 - val_loss: 352556768.0000
# Epoch 61/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 256967472.0000 - val_loss: 379497536.0000
# Epoch 62/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 245025648.0000 - val_loss: 345559200.0000
# Epoch 63/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 233982960.0000 - val_loss: 330481984.0000
# Epoch 64/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 226387376.0000 - val_loss: 350497440.0000
# Epoch 65/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 224324096.0000 - val_loss: 340486176.0000
# Epoch 66/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 224655856.0000 - val_loss: 337958944.0000
# Epoch 67/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 221988128.0000 - val_loss: 358355872.0000
# Epoch 68/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 205599296.0000 - val_loss: 371382400.0000
# Epoch 69/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 243386496.0000 - val_loss: 378702400.0000
# Epoch 70/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 219590576.0000 - val_loss: 361254528.0000
# Epoch 71/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 241947440.0000 - val_loss: 325044992.0000
# Epoch 72/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 236744336.0000 - val_loss: 322498208.0000
# Epoch 73/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 203330064.0000 - val_loss: 425222752.0000
# Epoch 74/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 235330672.0000 - val_loss: 386888736.0000
# Epoch 75/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 226895808.0000 - val_loss: 347904320.0000
# Epoch 76/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 209628656.0000 - val_loss: 338048384.0000
# Epoch 77/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 210937280.0000 - val_loss: 335013760.0000
# Epoch 78/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 219709344.0000 - val_loss: 358094592.0000
# Epoch 79/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 215263680.0000 - val_loss: 335920416.0000
# Epoch 80/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 210019232.0000 - val_loss: 326555040.0000
# Epoch 81/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 200291504.0000 - val_loss: 365103552.0000
# Epoch 82/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 219350528.0000 - val_loss: 353309536.0000
# Epoch 83/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 191325968.0000 - val_loss: 347275040.0000
# Epoch 84/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 197364304.0000 - val_loss: 332787360.0000
# Epoch 85/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 206365824.0000 - val_loss: 352645280.0000
# Epoch 86/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 183291744.0000 - val_loss: 338615680.0000
# Epoch 87/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 207207184.0000 - val_loss: 387871008.0000
# Epoch 88/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 203303968.0000 - val_loss: 366662304.0000
# Epoch 89/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 198921536.0000 - val_loss: 329804960.0000
# Epoch 90/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 191569008.0000 - val_loss: 331773952.0000
# Epoch 91/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 193470272.0000 - val_loss: 337224864.0000
# Epoch 92/100
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 225834784.0000 - val_loss: 341009888.0000

# %%
tahmin = model.predict(x_test).flatten()

print(f"R²  : {r2_score(y_test, tahmin):.4f}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, tahmin)):,.0f}")
print(f"MAE : {mean_absolute_error(y_test, tahmin):,.0f}")
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R²  : 0.9296
# RMSE: 17,958
# MAE : 8,181

# %%
#Loss Grafiği
plt.figure(figsize=(10, 4))
plt.plot(history.history['loss'],     label='Train Loss', color='steelblue')
plt.plot(history.history['val_loss'], label='Val Loss',   color='tomato')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
model.save('istanbul_rent_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# Bu çalışma kapsamında oluşturulan veri seti üzerinde farklı makine öğrenmesi ve derin öğrenme modelleri uygulanarak kira fiyatı tahmin performansları karşılaştırılmıştır. Elde edilen sonuçlara göre, en yüksek performans XGBRegressor modeli tarafından elde edilmiştir (R²: 0.937, RMSE: 16,984, MAE: 7,648). Gradient Boosting, Ridge, Linear Regression ve Lasso gibi modeller de görece yüksek başarı sağlamış ancak hata oranları bakımından XGBoost’un gerisinde kalmıştır. Derin öğrenme modeli ise R²: 0.9296, RMSE: 17,958 ve MAE: 8,181 değerleri ile güçlü bir performans sergilemiş, ancak en iyi sonucu veren modelin biraz altında kalmıştır.
